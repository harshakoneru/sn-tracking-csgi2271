# %%
# !python tools/run_bytetrack_soccernet.py image -f exps/yolox_x_10Ep_bytetrack_mot_17.py -c /scratch/hk3820/csgi2271_finalproject/YOLOX_outputs/yolox_x_10Ep_bytetrack_mot_17/latest_ckpt.pth.tar --fuse --save_result --fp16 --dataset test
# Out:
# 2023-12-07 11:11:38.920 | INFO     | __main__:main:255 - Args: Namespace(aspect_ratio_thresh=1.6, ckpt='/scratch/hk3820/csgi2271_finalproject/YOLOX_outputs/yolox_x_10Ep_bytetrack_mot_17/latest_ckpt.pth.tar', conf=None, dataset='test', demo='image', device=device(type='cuda'), exp_file='exps/yolox_x_10Ep_bytetrack_mot_17.py', experiment_name='yolox_x_10Ep_bytetrack_mot_17', fp16=True, fps=30, fuse=True, match_thresh=0.8, min_box_area=10, mot20=False, name=None, nms=None, save_result=True, track_buffer=30, track_thresh=0.5, trt=False, tsize=None)
# /ext3/miniconda3/envs/ByteTrack/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-12-07 11:11:40.282 | INFO     | __main__:main:265 - Model Summary: Params: 99.00M, Gflops: 987.11
# ...

# %%
# !!cd /scratch/hk3820/csgi2271_finalproject/YOLOX_outputs/yolox_x_10Ep_bytetrack_mot_17/track_vis/ && zip soccernet_bytetrack_mot_results.zip SNMOT-???.txt
# Out:
# ['  adding: SNMOT-116.txt (deflated 68%)',
#  '  adding: SNMOT-117.txt (deflated 68%)',
#  '  adding: SNMOT-118.txt (deflated 68%)',
#  '  adding: SNMOT-119.txt (deflated 68%)',
#  '  adding: SNMOT-120.txt (deflated 68%)',
#  '  adding: SNMOT-121.txt (deflated 69%)',
#  '  adding: SNMOT-122.txt (deflated 69%)',
#  '  adding: SNMOT-123.txt (deflated 69%)',
#  '  adding: SNMOT-124.txt (deflated 69%)',
#  '  adding: SNMOT-125.txt (deflated 69%)',
#  '  adding: SNMOT-126.txt (deflated 68%)',
#  '  adding: SNMOT-127.txt (deflated 70%)',
#  '  adding: SNMOT-128.txt (deflated 69%)',
#  '  adding: SNMOT-129.txt (deflated 69%)',
#  '  adding: SNMOT-130.txt (deflated 69%)',
#  '  adding: SNMOT-131.txt (deflated 69%)',
#  '  adding: SNMOT-132.txt (deflated 69%)',
#  '  adding: SNMOT-133.txt (deflated 69%)',
#  '  adding: SNMOT-134.txt (deflated 70%)',
#  '  adding: SNMOT-135.txt (deflated 69%)',
#  '  adding: SNMOT-136.txt (deflated 68%)',
#  '  adding: SNMOT-137.txt (deflated 68%)',
# ...

# %%
# !python tools/evaluate_soccernet_v3_tracking.py \
--TRACKERS_FOLDER_ZIP /scratch/hk3820/csgi2271_finalproject/YOLOX_outputs/yolox_x_10Ep_bytetrack_mot_17/track_vis/soccernet_bytetrack_mot_results.zip \
--GT_FOLDER_ZIP gt_test.zip \
--BENCHMARK SNMOT --DO_PREPROC False --SEQMAP_FILE tools/SNMOT-test.txt --TRACKERS_TO_EVAL test --SPLIT_TO_EVAL test --OUTPUT_SUB_FOLDER eval_results
# Out:
# /scratch/hk3820/csgi2271_finalproject
#
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /home/hk3820/.local/lib/python3.8/site-packages/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : False
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# PRINT_CONFIG         : True
# GT_FOLDER            : ./temp/gt
# TRACKERS_FOLDER      : ./temp
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['test']
# CLASSES_TO_EVAL      : ['pedestrian']
# BENCHMARK            : SNMOT
# SPLIT_TO_EVAL        : test
# INPUT_AS_ZIP         : False
# DO_PREPROC           : False
# TRACKER_SUB_FOLDER   : data
# OUTPUT_SUB_FOLDER    : eval_results
# TRACKER_DISPLAY_NAMES : None
# ...

# %%
import torch

# %%
m = torch.load("YOLOX_outputs/yolox_x_10Ep_bytetrack_mot_17_run2/best_ckpt.pth.tar", map_location="cpu")

# %%
m["start_epoch"]
# Out:
# 4

# %%
Average forward time: 88.33 ms, Average NMS time: 0.63 ms, Average inference time: 88.96 ms
Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.621
Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.944
Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.711
Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.219
Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.632
Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.703
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.453
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.678
Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.328
Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.694
Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.753

# %%
Average forward time: 87.81 ms, Average NMS time: 0.83 ms, Average inference time: 88.64 ms
Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.623
Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.944
Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.713
Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.453
Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.325
Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.695
Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.754
